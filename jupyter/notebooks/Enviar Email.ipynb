# %%
import sys
sys.path.append("/code/src/genesis")
import django
django.setup()

# %%
from django.core.mail import EmailMultiAlternatives, send_mail
from django.template.loader import render_to_string

from projects.models import Project
from datetime import datetime

project = Project.objects.first()

context = {
    "project": project,
    "deadline": datetime.now()
}

html_content = render_to_string("email/circularizacao.html", context)


email = EmailMultiAlternatives(
    subject="Circularizacão Teste",
    body=html_content,
    from_email="Onix SE <projetos@onixse.com>",
    to=["bruno.russian.i@gmail.com"],
)
email.attach_alternative(html_content, "text/html")
email.attach_file("static/attachments/circularizacao/foobar.pdf")
email.send()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/site-packages/django/template/utils.py in __getitem__(self, alias)
#      65         try:
# ---> 66             return self._engines[alias]
#      67         except KeyError:
#
# KeyError: 'django'
#
# During handling of the above exception, another exception occurred:
#
# ModuleNotFoundError                       Traceback (most recent call last)
# /usr/local/lib/python3.7/site-packages/django/template/backends/django.py in get_package_libraries(pkg)
#     120         try:
# --> 121             module = import_module(entry[1])
#     122         except ImportError as e:
#
# /usr/local/lib/python3.7/importlib/__init__.py in import_module(name, package)
#     126             level += 1
# --> 127     return _bootstrap._gcd_import(name[level:], package, level)
#     128
#
# /usr/local/lib/python3.7/importlib/_bootstrap.py in _gcd_import(name, package, level)
#
# /usr/local/lib/python3.7/importlib/_bootstrap.py in _find_and_load(name, import_)
#
# /usr/local/lib/python3.7/importlib/_bootstrap.py in _find_and_load_unlocked(name, import_)
#
# /usr/local/lib/python3.7/importlib/_bootstrap.py in _load_unlocked(spec)
#
# /usr/local/lib/python3.7/importlib/_bootstrap_external.py in exec_module(self, module)
#
# /usr/local/lib/python3.7/importlib/_bootstrap.py in _call_with_frames_removed(f, *args, **kwds)
#
# /code/src/genesis/utils/templatetags/inline_css.py in <module>
#       3
# ----> 4 import cssutils
#       5 from django import template
#
# ModuleNotFoundError: No module named 'cssutils'
#
# During handling of the above exception, another exception occurred:
#
# InvalidTemplateLibrary                    Traceback (most recent call last)
# /tmp/ipykernel_12/2285277587.py in <module>
#      12 }
#      13
# ---> 14 html_content = render_to_string("email/circularizacao.html", context)
#      15
#      16
#
# /usr/local/lib/python3.7/site-packages/django/template/loader.py in render_to_string(template_name, context, request, using)
#      59         template = select_template(template_name, using=using)
#      60     else:
# ---> 61         template = get_template(template_name, using=using)
#      62     return template.render(context, request)
#      63
#
# /usr/local/lib/python3.7/site-packages/django/template/loader.py in get_template(template_name, using)
#      10     """
#      11     chain = []
# ---> 12     engines = _engine_list(using)
#      13     for engine in engines:
#      14         try:
#
# /usr/local/lib/python3.7/site-packages/django/template/loader.py in _engine_list(using)
#      64
#      65 def _engine_list(using=None):
# ---> 66     return engines.all() if using is None else [engines[using]]
#
# /usr/local/lib/python3.7/site-packages/django/template/utils.py in all(self)
#      88
#      89     def all(self):
# ---> 90         return [self[alias] for alias in self]
#      91
#      92
#
# /usr/local/lib/python3.7/site-packages/django/template/utils.py in <listcomp>(.0)
#      88
#      89     def all(self):
# ---> 90         return [self[alias] for alias in self]
#      91
#      92
#
# /usr/local/lib/python3.7/site-packages/django/template/utils.py in __getitem__(self, alias)
#      79             backend = params.pop('BACKEND')
#      80             engine_cls = import_string(backend)
# ---> 81             engine = engine_cls(params)
#      82
#      83             self._engines[alias] = engine
#
# /usr/local/lib/python3.7/site-packages/django/template/backends/django.py in __init__(self, params)
#      23         options.setdefault('file_charset', settings.FILE_CHARSET)
#      24         libraries = options.get('libraries', {})
# ---> 25         options['libraries'] = self.get_templatetag_libraries(libraries)
#      26         super().__init__(params)
#      27         self.engine = Engine(self.dirs, self.app_dirs, **options)
#
# /usr/local/lib/python3.7/site-packages/django/template/backends/django.py in get_templatetag_libraries(self, custom_libraries)
#      41         applications and the supplied custom_libraries argument.
#      42         """
# ---> 43         libraries = get_installed_libraries()
#      44         libraries.update(custom_libraries)
#      45         return libraries
#
# /usr/local/lib/python3.7/site-packages/django/template/backends/django.py in get_installed_libraries()
#     106
#     107         if hasattr(pkg, '__path__'):
# --> 108             for name in get_package_libraries(pkg):
#     109                 libraries[name[len(candidate) + 1:]] = name
#     110
#
# /usr/local/lib/python3.7/site-packages/django/template/backends/django.py in get_package_libraries(pkg)
#     123             raise InvalidTemplateLibrary(
#     124                 "Invalid template library specified. ImportError raised when "
# --> 125                 "trying to load '%s': %s" % (entry[1], e)
#     126             )
#     127
#
# InvalidTemplateLibrary: Invalid template library specified. ImportError raised when trying to load 'utils.templatetags.inline_css': No module named 'cssutils'

# %%
pip freeze
# Out:
# argon2-cffi==20.1.0
# asgiref==3.4.1
# async-generator==1.10
# attrs==21.2.0
# backcall==0.2.0
# backports.entry-points-selectable==1.1.0
# bleach==3.3.1
# boto3==1.17.19
# botocore==1.20.24
# certifi==2021.5.30
# cffi==1.14.6
# cfgv==3.3.0
# charset-normalizer==2.0.3
# click==8.0.1
# coverage==5.5
# debugpy==1.4.1
# decorator==5.0.9
# defusedxml==0.7.1
# diff-match-patch==20200713
# distlib==0.3.2
# Django==2.2.19
# django-admin-rangefilter==0.7.0
# django-environ==0.4.3
# django-extensions==3.1.3
# django-import-export==2.3.0
# django-localflavor==2.2
# django-model-utils==4.0.0
# django-ses==2.2.0
# django-storages==1.11.1
# django-suit @ git+https://github.com/darklow/django-suit.git@0d854c9b5e81adf9b9ea2ca9ee0a2856dcef5e15
# dparse==0.5.1
# entrypoints==0.3
# et-xmlfile==1.0.1
# factory-boy==3.2.0
# Faker==8.10.1
# filelock==3.0.12
# flake8==3.9.2
# freezegun==1.1.0
# future==0.18.2
# identify==2.2.11
# idna==3.2
# importlib-metadata==3.10.1
# inflection==0.5.1
# iniconfig==1.1.1
# ipdb==0.13.9
# ipykernel==6.0.3
# ipython==7.25.0
# ipython-genutils==0.2.0
# ipywidgets==7.6.3
# jedi==0.18.0
# Jinja2==3.0.1
# jmespath==0.10.0
# jsonschema==3.2.0
# jupyter==1.0.0
# jupyter-client==6.1.12
# jupyter-console==6.4.0
# jupyter-core==4.7.1
# jupyterlab-pygments==0.1.2
# jupyterlab-widgets==1.0.0
# MarkupPy==1.14
# MarkupSafe==2.0.1
# matplotlib-inline==0.1.2
# mccabe==0.6.1
# mistune==0.8.4
# multidict==5.1.0
# mysqlclient==1.4.2
# nbclient==0.5.3
# nbconvert==6.1.0
# nbformat==5.1.3
# nest-asyncio==1.5.1
# nodeenv==1.6.0
# notebook==6.4.0
# odfpy==1.4.1
# openpyxl==3.0.7
# packaging==21.0
# pandocfilters==1.4.3
# parso==0.8.2
# pep517==0.11.0
# pexpect==4.8.0
# pickleshare==0.7.5
# pip-tools==6.2.0
# platformdirs==2.0.2
# pluggy==0.13.1
# pre-commit==2.13.0
# prometheus-client==0.11.0
# prompt-toolkit==3.0.19
# ptyprocess==0.7.0
# py==1.10.0
# pycodestyle==2.7.0
# pycparser==2.20
# pyflakes==2.3.1
# Pygments==2.9.0
# pyparsing==2.4.7
# pyrsistent==0.18.0
# pytest==6.2.4
# pytest-cov==2.12.1
# pytest-django==4.4.0
# pytest-factoryboy==2.1.0
# pytest-faker==2.0.0
# pytest-pythonpath==0.7.3
# pytest-vcr==1.0.2
# python-dateutil==2.8.1
# python-stdnum==1.16
# pytz==2021.1
# PyYAML==5.4.1
# pyzmq==22.1.0
# qtconsole==5.1.1
# QtPy==1.9.0
# requests==2.26.0
# s3transfer==0.3.4
# safety==1.10.3
# Send2Trash==1.7.1
# six==1.15.0
# sqlparse==0.4.1
# tablib==3.0.0
# terminado==0.10.1
# testpath==0.5.0
# text-unidecode==1.3
# toml==0.10.2
# tomli==1.0.4
# tornado==6.1
# traitlets==5.0.5
# typing-extensions==3.10.0.0
# urllib3==1.26.3
# vcrpy==4.1.1
# virtualenv==20.6.0
# wcwidth==0.2.5
# webencodings==0.5.1
# widgetsnbextension==3.5.1
# wrapt==1.12.1
# xlrd==2.0.1
# xlwt==1.3.0
# yarl==1.6.3
# zipp==3.5.0
# Note: you may need to restart the kernel to use updated packages.
